# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import *
#%matplotlib inline

# %% [markdown]
# Purpose: Determine whether the drone  or its payload contributes to any noise detected by the spectrum analyzer during flight testing at the Sevilleta LWA. Test equipment used was a Fieldfox spectrum analyzer, biconical antenna, and low noise amplifier. Background noise spectra was recorded before each flight during the field test, and several spectra were taken during each flight as the drone completed its flight path. Each flight spectra was compared to its respective background to determine if there is an excess of noise above the background, and if any of the noise is being emitted into the band of interest, 70MHz.
#
# Characterizing the Background Noise:
# Each day the drone completed several flight paths. Prior to the start of each flight path a spectra of the background was taken with the drone, payload, and any other heavily emitting electronics (aside from the LWA antennas) turned off. This spectra would be used as a basis to compare to the spectra taken during the flight path when the drone and payload are turned on. A recurring problem was the noise floor of the background occasionally being higher than the noise floor during the flight which made it difficult for comparison. On the third day only three of the 12 flight spectra taken match the noise floor of the associated background. Day four had better results with 11 of the 17 flights having matching noise floors.
#
# The following are examples of flight spectra with unmatching noise floors:

# %%
#background
#back1 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\DAY3BACK2.csv', skiprows = 32))
back1 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\DAY3BACK2.csv', skiprows = 32, nrows=148, delimiter = ',',engine = 'python'))
#flight5 data
data2= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F5.csv', skiprows = 28))
data2= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F5.csv', skiprows = 28, nrows=148, delimiter = ',',engine = 'python'))

freq1 = back1[:-1,0]
powb1 = back1[:-1,1]
powd2 = data2[:-1,1]
f1 = freq1.astype(float)
pb1 = powb1.astype(float)
pd2 = powd2.astype(float)
fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f1)/10**6, pb1, 'k', label= 'Flight 2 back 1')
plot((f1)/10**6, pd2, 'b', label= 'Flight 5-1')
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
xticks(fontsize=22)
yticks(fontsize=22)
legend(fontsize=15)
grid()
#savefig('Day 3, Flight 5-1')

# %%
#background
back2 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_B.csv', skiprows = 27))

#flight5 data
data4= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_1.csv', skiprows = 27))

freq2 = back2[:-1,0]
powb2 = back2[:-1,1]
powd4 = data4[:-1,1]
f2 = freq2.astype(float)
pb2 = powb2.astype(float)
pd4 = powd4.astype(float)
fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f2)/10**6, pb2, 'k', label= 'Flight 6 back')
plot((f2)/10**6, pd4, 'b', label= 'Flight 6-1')
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
legend(fontsize=15)
grid()
#savefig('Day 3, Flight 6-1')

# %%
#background
back3 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_B.csv', skiprows = 33))

#flight7-3 data
data10= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_3.csv', skiprows = 28))

freq3 = back3[:-1,0]
powb3 = back3[:-1,1]
powd10 = data10[:-1,1]
f3 = freq3.astype(float)
pb3 = powb3.astype(float)
pd10 = powd10.astype(float)
fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f3)/10**6, pb3, 'k', label= 'Flight 7 back')
plot((f3)/10**6, pd10, 'b', label= 'Flight 7-3')
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
legend(fontsize=15)
xticks(fontsize=22 )
yticks(fontsize=22 ) 
grid()
#savefig('Day 3, Flight 7-3')

# %%
#background
back3 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_B.csv', skiprows = 33))

#flight7-4 data
data11= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_4.csv', skiprows = 28))

freq3 = back3[:-1,0]
powb3 = back3[:-1,1]
powd11 = data11[:-1,1]
f3 = freq3.astype(float)
pb3 = powb3.astype(float)
pd11 = powd11.astype(float)
fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f3)/10**6, pb3, 'k', label= 'Flight 7 back')
plot((f3)/10**6, pd11, 'b', label= 'Flight 7-4')
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
xticks(fontsize=22 )
yticks(fontsize=22 ) 
legend(fontsize=15)
grid()

# %% [markdown]
# Analysis of Spectral Plots with Matching Noise Floor
#
# Day 3
# Flights 7-1 and 7-2 have similar profiles with the background. There are noise spikes within 5 MHz on both sides of the 70MHz signal which matches what was picked up by the background. There is an increase in power level between 40-50MHz that is above the background spectra in both flights.

# %%
#background
back3 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_B.csv', skiprows = 33))

#flight7 data
data8= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_1.csv', skiprows = 33))

freq3 = back3[:-1,0]
powb3 = back3[:-1,1]
powd8 = data8[:-1,1]
f3 = freq3.astype(float)
pb3 = powb3.astype(float)
pd8 = powd8.astype(float)
fig = figure(figsize=(20,10))
ax = axes()
#ax.xaxis.set_major_locator(MultipleLocator(10))
plot( (f3)/10**6, pb3,'k', label= 'Flight 7 background')
plot((f3)/10**6, pd8, 'darkred', label= 'Flight 7-1 background')
#plot(bgsorted[:,0,-2]/1e6,bgsorted[:,1,-2], 'dimgray', label='80% Confidence Bound')
fig.suptitle('Day 3, Flight 7-1', fontsize=25)
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
xticks(fontsize=18 )
yticks(fontsize=18 )
legend(fontsize=15)
grid()

# %%
#background
back3 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_B.csv', skiprows = 33))

#flight7-2 data
data9= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_2.csv', skiprows = 28))

freq3 = back3[:-1,0]
powb3 = back3[:-1,1]
powd9 = data9[:-1,1]
f3 = freq3.astype(float)
pb3 = powb3.astype(float)
pd9 = powd9.astype(float)
fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f3)/10**6, pb3, 'k', label= 'Flight 7 background')
plot((f3)/10**6, pd9, 'darkred', label= 'Flight 7-2 background')
#plot(bgsorted[:,0,-2]/1e6,bgsorted[:,1,-2], 'dimgray', label='80% Confidence Bound')
fig.suptitle('Day 3, Flight 7-2', fontsize=25)
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
xticks(fontsize=18 )
yticks(fontsize=18 )
legend(fontsize=15)
grid()

# %% [markdown]
# Day 4
# Two main flights and a signal phase test were completed. From the two main flights there were two spectra that matched the noise floor of the background, flights 1-1 and 2-1. There are no power increases near the transmitted signal for either flight, but flight 2-1 shows a slight increase in the power level above the background beneath 60 MHz.

# %%
#Flight 1-1
#background
back1 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4FB.csv', skiprows = 29))

#flight1-1 data
data1= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F1.csv', skiprows = 29))

freq1 = back1[:-1,0]
powb1 = back1[:-1,1]
powd1 = data1[:-1,1]
f1 = freq1.astype(float)
pb1 = powb1.astype(float)
pd1 = powd1.astype(float)
fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f1)/10**6, pb1, 'k', label= 'Flight 1 back')
plot((f1)/10**6, pd1, 'darkred', label= 'Flight 1-1')
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
fig.suptitle('Day 4, Flight 1-1', fontsize=25)
xticks(fontsize=18 )
yticks(fontsize=18 )
legend(fontsize=15)
grid()

#Flight 2-1
#background
back2 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4FB_2.csv', skiprows = 29))

#flight2-1 data
data4= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F2_1.csv', skiprows = 29))

freq2 = back2[:-1,0]
powb2 = back2[:-1,1]
powd4 = data4[:-1,1]
f2 = freq2.astype(float)
pb2 = powb2.astype(float)
pd4 = powd4.astype(float)
fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f2)/10**6, pb2, 'k', label= 'Flight 2 background')
plot((f2)/10**6, pd4, 'darkred', label= 'Flight 2-1 background')
fig.suptitle('Day 4, Flight 2-1', fontsize=25)
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
xticks(fontsize=18 )
yticks(fontsize=18 )
legend(fontsize=15)
grid()

# %% [markdown]
# The signal phase test flights had a quiet background with very high power levels at a wide range of frequencies, however the flight spectra only had high power levels at a very narrow range of frequencies, none of which were above the power level of the background except for flights 3-6, 3-7, and 3-8. At these particular flights, the drone was oriented north to south and was 45 m, 23 m, and 10 m respectively above the biconical antenna. At 45m high, there were two spikes close to the same power level of the transmitted signal within a 5 MHz range on both sides.

# %%
#Signal phase tests, day 4
#Flight 3-7
#background

plt.figure(figsize=(12,6)) 
back3 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_1.csv', skiprows = 29))

#flight 3-7 data
data15= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_7.csv', skiprows = 29))

plt.subplot(221)
freq3 = back3[:-1,0]
powb3 = back3[:-1,1]
powd15 = data15[:-1,1]
f3 = freq3.astype(float)
pb3 = powb3.astype(float)
pd15 = powd15.astype(float)
#fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f2)/10**6, pb3, 'k', label= 'Flight 3 background')
plot((f2)/10**6, pd15, 'darkred', label= 'Flight 3-7 background')
fig.suptitle('Day 4, Flight 3-6', fontsize=25)
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
fig.suptitle('Day 4, Flight 3-7', fontsize=25)
xticks(fontsize=18 )
yticks(fontsize=18 )
legend(fontsize=15)
grid()

#Flight 3-8
#background
back3 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_1.csv', skiprows = 29))

#flight 3-8 data
data16= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_8.csv', skiprows = 29))

plt.subplot(222)
freq3 = back3[:-1,0]
powb3 = back3[:-1,1]
powd16 = data16[:-1,1]
f3 = freq3.astype(float)
pb3 = powb3.astype(float)
pd16 = powd16.astype(float)
#fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f2)/10**6, pb3, 'k', label= 'Flight 3 background')
plot((f2)/10**6, pd16, 'darkred', label= 'Flight 3-8 background')
fig.suptitle('Day 4, Flight 3-8', fontsize=25)
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
fig.suptitle('Day 4, Flight 3-8', fontsize=25)
xticks(fontsize=18 )
yticks(fontsize=18 )
legend(fontsize=15)
grid()

#flight3-9 data
data17= np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_9.csv', skiprows = 29))
plt.subplot(223)
freq3 = back3[:-1,0]
powb3 = back3[:-1,1]
powd17 = data17[:-1,1]
f3 = freq3.astype(float)
pb3 = powb3.astype(float)
pd17 = powd17.astype(float)
#fig = figure(figsize=(20,10))
ax = axes()
ax.xaxis.set_major_locator(MultipleLocator(10))
plot((f2)/10**6, pb3, 'k', label= 'Flight 3 background')
plot((f2)/10**6, pd17, 'darkred', label= 'Flight 3-9 background')
fig.suptitle('Day 4, Flight 3-9', fontsize=25)
xlabel('Frequency in MHz', fontsize=18)
ylabel('Power in dBm', fontsize=18)
fig.suptitle('Day 4, Flight 3-9', fontsize=25)
xticks(fontsize=18 )
yticks(fontsize=18 )
legend(fontsize=15)
grid()

plt.show()

# %% [markdown]
# Discussion
#
# To begin, all of the main flight background spectra were collected into an array and a for loop was used to iterate through each spectra file and plotting them.

# %%
#Final Confidence Bound Code

bgrounds1=[r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\DAY3BACK2.csv',
         r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_B.csv',
        r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_B.csv',
         r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4FB.csv',
        r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4FB_2.csv' ]

# %% [markdown]
# A function was created to iterate through each spectra in the array, skip the first several lines, and append the values in columns 0 and 1 (frequency and power columns) into another array which is returned.

# %%
def load_fieldfox(filename):
    f=open(filename)
    lines=f.readlines()
    d=[]
    for line in lines:
        if line[0]=='!': continue
        if line.startswith('BEGIN') or line.startswith('END') :continue
        vals=line.split(',')    
        d.append([vals[0],vals[1]])
    return np.array(d,dtype=np.float)

# %% [markdown]
# We create a for loop that utilizes the function to go through each file except the first and append the values to the the array bgrounds. 'bgrounds' is then stacked along axis -1 and sorted along axis -2

# %%
bgrounds1=[]
for bg in bgrounds1[1:]: #[1:] skips the first file, which is a spectra with the highest noise floor
    
    bgrounds1.append(load_fieldfox(bg)) #

bgrounds1=np.stack(bgrounds1, axis=-1)

bgsorted1=np.sort(bgrounds1, axis=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-7635df12134c> in <module>
#       4     bgrounds1.append(load_fieldfox(bg)) #
#       5
# ----> 6 bgrounds1=np.stack(bgrounds1, axis=-1)
#       7
#       8 bgsorted1=np.sort(bgrounds1, axis=2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\shape_base.py in stack(arrays, axis, out)
#     410     arrays = [asanyarray(arr) for arr in arrays]
#     411     if not arrays:
# --> 412         raise ValueError('need at least one array to stack')
#     413
#     414     shapes = {arr.shape for arr in arrays}
#
# ValueError: need at least one array to stack

# %% [markdown]
# 'bgrounds' is then plotted in a figure one by one in multi colors and the confidence bound is plotted in black. The first observation is that confidence bound isn't what we expected it to be.

# %%
fig=figure()
plot(bgrounds1[:,0,:]/1e6, bgrounds1[:,1,:]) #all bground plots plot(x=freq,y=pwr)
#plot(bgrounds[:,1,:]) #[dim1,dim2,dim3], 1-power in 2nd dim. also plots bgrounds but x=#ofpnts
#plot(bgsorted[:,1,-2], 'k', label='80% Confidence Bound') #black line=80% confidence interval. x=#points
plot(bgsorted1[:,0,-2]/1e6,bgsorted1[:,1,-2], 'k', label='Confidence Bound')

fig.suptitle('Day 3 and 4 Backgrounds', fontsize=20)
xlabel('Frequency in MHz', fontsize=15)
ylabel('Power in dBm', fontsize=15)
legend(fontsize=10)
grid()

# %%
#day 3 backgrounds
bgrounds2=[r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\DAY3BACK2.csv',
          r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_B.csv',
          r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_B.csv',
          r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4FB.csv',
          r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4FB_2.csv']
# back1 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\DAY3BACK2.csv', skiprows = 32, nrows=148, delimiter = ',',engine = 'python'))
# back2 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_B.csv', skiprows = 28,  nrows = 340, delimiter = ',', engine = 'python'))
# back3 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_B.csv', skiprows = 33,  nrows = 339, delimiter = ',', engine = 'python'))

# #day 4 backgrounds
# back4 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4FB.csv', skiprows = 32, nrows = 339, delimiter = ',', engine = 'python'))
# back5 = np.array(pd.read_csv(r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4FB_2.csv', skiprows = 28,  nrows = 339, delimiter = ',', engine = 'python'))

# alldaybacks = [back1, back2, back3, back4, back5]

#Plot of all background spectra with confidence bound

# for i, back in enumerate(alldaybacks): #enumerate lets you reference both the object and the index of the object in a list
#     x = [] #reset these for each file
#     y = [] #reset these for each file
#     for row in back: #we want to look through each day, not back1
#         absorted=np.sort(back, axis=1)
#         x.append(float(row[0])/1e6) 
#         y.append(float(row[1]) + i) #no offset
        
   
#     #plot all spectra in one window
#     plt.plot(x,y, '0.8') 
#     plt.xlabel('Frequency (MHz)')
#     plt.ylabel('Power (dBm)')
#     plt.title("All Background Plots")
    
#     #highlight the max bound spectra
# plot(bgsorted[:,0,-2]/1e6,bgsorted[:,1,-2], 'dimgray', label='80% Confidence Bound')

bgrounds2=[]
for bg in bgrounds2[1:]: #[1:] skips the first file, which is a spectra with the highest noise floor
    
    bgrounds2.append(load_fieldfox(bg)) #

bgrounds2=np.stack(bgrounds2, axis=-1)

bgsorted2=np.sort(bgrounds2, axis=2)

fig=figure()
plot(bgrounds2[:,0,:]/1e6, bgrounds2[:,1,:]) #all bground plots plot(x=freq,y=pwr)
#plot(bgrounds[:,1,:]) #[dim1,dim2,dim3], 1-power in 2nd dim. also plots bgrounds but x=#ofpnts
#plot(bgsorted[:,1,-2], 'k', label='80% Confidence Bound') #black line=80% confidence interval. x=#points
plot(bgsorted2[:,0,-2]/1e6,bgsorted2[:,1,-2], 'k', label='Confidence Bound 2')

fig.suptitle('All Backgrounds', fontsize=20)
xlabel('Frequency in MHz', fontsize=15)
ylabel('Power in dBm', fontsize=15)
legend(fontsize=10)
grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-825b778e6ff7> in <module>
#      40     bgrounds2.append(load_fieldfox(bg)) #
#      41
# ---> 42 bgrounds2=np.stack(bgrounds2, axis=-1)
#      43
#      44 bgsorted2=np.sort(bgrounds2, axis=2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\shape_base.py in stack(arrays, axis, out)
#     410     arrays = [asanyarray(arr) for arr in arrays]
#     411     if not arrays:
# --> 412         raise ValueError('need at least one array to stack')
#     413
#     414     shapes = {arr.shape for arr in arrays}
#
# ValueError: need at least one array to stack

# %%
#Days 3 ad 4 flight spectra with confidence bound

flightfiles = [#r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F5.csv', 
           #r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F5_2.csv', 
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_1.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_2.csv',
            r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_3.csv',
            r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F6_4.csv',
            r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_1.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_2.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_3.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_4.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_5.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 3 10-25\F7_6.csv',
           
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F1.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F1_2.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F1_3.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F2_1.csv',
          r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F2_2.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F2_3.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F2_4.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F2_5.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F2_6.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_1.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_2.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_3.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_4.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_5.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_6.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_7.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_8.csv',
           r'C:\Users\shani\Documents\Work\LoCo Labs\ECHO\Sevilleta\Day 4 10-26\D4F3_9.csv']

flightspectra=[]
for flight in flightfiles:
    
    flightspectra.append(load_fieldfox(flight)) 

flightspectra=np.stack(flightspectra, axis=-1)
flightsorted=np.sort(flightspectra, axis=2)

fig=figure()
plot(flightspectra[:,0,:]/1e6, flightspectra[:,1,:], 'silver') #all flight plots plot(x=freq,y=pwr)
plot(bgsorted[:,0,-2]/1e6,bgsorted[:,1,-2], 'k', label='Confidence Bound')
plot(flightsorted[:,0,-1]/1e6,flightsorted[:,1,-1], 'orange', label='Max Flight Spectra')

#plot(flightspectra[:,1,:]) #[dim1,dim2,dim3], 1-power in 2nd dim. also plots flight but x=#ofpnts
#plot(flightsorted[:,1,-2], 'k', label='80% Confidence Bound') #black line=80% confidence interval. x=#points

fig.suptitle('Day 3 and 4 Flights', fontsize=20)
xlabel('Frequency in MHz', fontsize=15)
ylabel('Power in dBm', fontsize=15)
legend(fontsize=10)
grid()
#savefig('All flights w/CB')
