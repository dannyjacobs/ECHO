# %%
# %matplotlib inline
from matplotlib.pyplot import *
import numpy as np

# %%
D = np.loadtxt('spec_05_31_16_18:10:43.txt',delimiter=',')

# %%
figure(figsize=(10,10))
freqs = D[0,1:]-0.005
print freqs[0],np.diff(freqs)[0]
myfreq =137.500
mychan = np.where(np.abs(freqs-myfreq).min()==np.abs(freqs-myfreq))[0]
print mychan
clf()
t=D[:,0]-D[0,0]
plot(t,
    D[:,mychan])
plot(t,D[:,mychan-10])
plot(t,D[:,mychan+10])
ylim(-100,-20)
xlim(1300,2200)
grid()
# Out:
# 126.997 0.00500000000001
# [2151]

# %%
figure(figsize=(10,10))
print t[650]
plot(freqs,D[650,1:])
axvline(
    137.5)
xlim(136,140)
# Out:
# 1437.0
# (136, 140)
